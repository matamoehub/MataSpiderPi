# %% [markdown]
# # Lesson 6 - Tracking and Tags
#
# Track targets, inspect AprilTags, and respond to what the camera sees.

# %% [markdown]
# ## Starter Flow
#
# 1. Load the classroom libraries.
# 2. Try the example cell.
# 3. Edit the challenge cell to make the robot do something new.

# %%
from lesson_header import *

bot.display.text("Lesson Ready", "SpiderPi", seconds=1.0)

# %%
bot.move.forward(0.5)
bot.move.turn_left(0.4)
bot.move.stop()

# %%
bot.actions.wave()

# %%
bot.arm.home()
bot.arm.open_gripper()

# %%
bot.vision.detect_color('red')

# %%
# Your challenge: change this sequence to match the lesson goal.
